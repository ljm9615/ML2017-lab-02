# %%
# write your code here
from sklearn.datasets import load_svmlight_file
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import random


def get_data(path):
    data = load_svmlight_file(path)
    return data[0].toarray(), data[1]


def sigmoid(x):
    return 1.0 / (1 + np.exp(-x))


def get_loss(X, y, w, b):
    loss = 0
    for i in range(X.shape[0]):
        y_ = sigmoid(np.dot(X[i].data, w) + b)
        if y_ > 0.5:
            y_ = 1
        else:
            y_ = -1
        loss += (y[i] - y_) * (y[i] - y_) * 0.5
    return loss / X.shape[0]


def compute_gradient(X, y, w, b, sample_indices):
    # loss_function 对w，b的偏导
    G_w = 0
    G_b = 0
    for i in sample_indices:
        y_ = sigmoid(np.dot(X[i].data, w) + b)
        if y_ > 0.5:
            y_ = 1
        else:
            y_ = -1
        G_w += (y[i] - y_) * X[i].data * (-1)
        G_b += y_ - y[i]
    G_w = G_w / len(sample_indices)
    G_b = G_b / len(sample_indices)

    # 更新参数
    w = w - learning_rate * G_w
    b = b - learning_rate * G_b

    return w, b


def NAG(X, y, w, b, v_, learning_rate, sample_indices):
    v_w = v_[:-1]
    v_b = v_[-1:]
    Gamma = 0.9
    # loss_function 对w，b的偏导
    G_w = 0
    G_b = 0
    for i in sample_indices:
        y_ = sigmoid(np.dot(X[i].data, w - Gamma * v_w) + b - Gamma * v_b)
        if y_ > 0.5:
            y_ = 1
        else:
            y_ = -1
        G_w += (y[i] - y_) * X[i].data * (-1)
        G_b += y_ - y[i]
    G_w = G_w / len(sample_indices)
    G_b = G_b / len(sample_indices)

    # 更新参数
    v_w = Gamma * v_w + learning_rate * G_w
    v_b = Gamma * v_b + learning_rate * G_b
    w = w - v_w
    b = b - v_b

    return w, b, np.concatenate([v_w, v_b])


def RMSProp(X, y, w, b, Gt, learning_rate, sample_indices):
    # loss_function 对w，b的偏导
    G_w = 0
    G_b = 0
    Gt_w = Gt[:-1]
    Gt_b = Gt[-1:]
    Gamma = 0.9
    epsilon = np.exp(-8)
    for i in sample_indices:
        y_ = sigmoid(np.dot(X[i].data, w) + b)
        if y_ > 0.5:
            y_ = 1
        else:
            y_ = -1
        G_w += (y[i] - y_) * X[i].data * (-1)
        G_b += y_ - y[i]

    G_w = G_w / len(sample_indices)
    G_b = G_b / len(sample_indices)

    # 更新参数
    Gt_w = Gt_w * Gamma + (1 - Gamma) * np.multiply(G_w, G_w)
    Gt_b = Gt_b * Gamma + (1 - Gamma) * np.multiply(G_b, G_b)

    w = w - np.multiply(learning_rate * pow(Gt_w + epsilon, -1/2), G_w)
    b = b - np.multiply(learning_rate * pow(Gt_b + epsilon, -1/2), G_b)

    return w, b, np.concatenate([Gt_w, Gt_b])


def AdaDelta(X, y, w, b, Gt, delta, sample_indices):
    # loss_function 对w，b的偏导
    G_w = 0
    G_b = 0
    Gt_w = Gt[:-1]
    Gt_b = Gt[-1:]
    delta_w = delta[:-1]
    delta_b = delta[-1:]
    Gamma = 0.95
    epsilon = pow(10, -8)
    for i in sample_indices:
        y_ = sigmoid(np.dot(X[i].data, w) + b)
        if y_ > 0.5:
            y_ = 1
        else:
            y_ = -1
        G_w += (y[i] - y_) * X[i].data * (-1)
        G_b += y_ - y[i]

    G_w = G_w / len(sample_indices)
    G_b = G_b / len(sample_indices)

    # 更新参数
    Gt_w = Gt_w * Gamma + (1 - Gamma) * np.multiply(G_w, G_w)
    Gt_b = Gt_b * Gamma + (1 - Gamma) * np.multiply(G_b, G_b)
    step_w = np.multiply((-1) * pow(delta_w + epsilon, 1/2) * pow(Gt_w + epsilon, -1/2), G_w)
    step_b = np.multiply((-1) * pow(delta_b + epsilon, 1 / 2) * pow(Gt_b + epsilon, -1 / 2), G_b)
    w = w + step_w
    b = b + step_b
    delta_w = Gamma * delta_w + np.multiply((1 - Gamma) * step_w, step_w)
    delta_b = Gamma * delta_b + np.multiply((1 - Gamma) * step_b, step_b)

    return w, b, np.concatenate([Gt_w, Gt_b]), np.concatenate([delta_w, delta_b])


def Adam(X, y, w, b, Gt, mt, sample_indices, learning_rate, t):
    # loss_function 对w，b的偏导
    G_w = 0
    G_b = 0
    Gt_w = Gt[:-1]
    Gt_b = Gt[-1:]
    mt_w = mt[:-1]
    mt_b = mt[-1:]
    Beta = 0.9
    Gamma = 0.999
    epsilon = pow(10, -8)
    for i in sample_indices:
        y_ = sigmoid(np.dot(X[i].data, w) + b)
        if y_ > 0.5:
            y_ = 1
        else:
            y_ = -1
        G_w += (y[i] - y_) * X[i].data * (-1)
        G_b += y_ - y[i]

    G_w = G_w / len(sample_indices)
    G_b = G_b / len(sample_indices)

    # 更新参数
    mt_w = mt_w * Beta + (1 - Beta) * G_w
    mt_b = mt_b * Beta + (1 - Beta) * G_b
    Gt_w = Gt_w * Gamma + (1 - Gamma) * np.multiply(G_w, G_w)
    Gt_b = Gt_b * Gamma + (1 - Gamma) * np.multiply(G_b, G_b)
    alpha = learning_rate * pow(1 - pow(Gamma, t), 1/2) * pow(1 - pow(Beta, t), -1/2)
    w = w - alpha * mt_w * pow(Gt_w + epsilon, -1/2)
    b = b - alpha * mt_b * pow(Gt_b + epsilon, -1/2)
    
    return w, b, np.concatenate([Gt_w, Gt_b]), np.concatenate([mt_w, mt_b])


def get_NAG(epoch, learning_rate):
    
    # 初始化参数
    w = np.random.normal(size=123)
    b = np.random.normal(size=1)
    v = np.zeros(124)

    # 记录验证集的loss随迭代次数的值
    val_losses = []

    for num in range(epoch):
        # 通过SGD更新参数，随机选择10个样本
        sample_indices = random.sample(range(X_test.shape[0]), 100)

        # 获得loss
        val_loss = get_loss(X_test, y_test, w, b)

        w, b, v = NAG(X_test, y_test, w, b, v, learning_rate, sample_indices)

        # 将loss加入列表
        val_losses.append(val_loss)
        
        print("NAG: ", num, val_loss)
    return val_losses


def get_RMSProp(epoch, learning_rate):
    # 初始化参数
    w = np.random.normal(size=123)
    b = np.random.normal(size=1)
    Gt = np.zeros(124)

    # 记录验证集的loss随迭代次数的值
    val_losses = []

    for num in range(epoch):
        # 通过SGD更新参数，随机选择10个样本
        sample_indices = random.sample(range(X_test.shape[0]), 100)

        # 获得loss
        val_loss = get_loss(X_test, y_test, w, b)

        w, b, Gt = RMSProp(X_test, y_test, w, b, Gt, learning_rate, sample_indices)

        # 将loss加入列表
        val_losses.append(val_loss)
        print("RMSProp: ", num, val_loss)
    return val_losses


def get_AdaDelta(epoch):
    # 初始化参数
    w = np.random.normal(size=123)
    b = np.random.normal(size=1)
    Gt = np.zeros(124)
    delta = np.zeros(124)

    # 记录验证集的loss随迭代次数的值
    val_losses = []

    for num in range(epoch):
        # 通过SGD更新参数，随机选择10个样本
        sample_indices = random.sample(range(X_test.shape[0]), 100)

        # 获得loss
        val_loss = get_loss(X_test, y_test, w, b)

        w, b, Gt, delta = AdaDelta(X_test, y_test, w, b, Gt, delta, sample_indices)

        # 将loss加入列表
        val_losses.append(val_loss)
        print("AdaDelta: ", num, val_loss)
    return val_losses


def get_Adam(epoch, learning_rate):
    # 初始化参数
    w = np.random.normal(size=123)
    b = np.random.normal(size=1)
    Gt = np.zeros(124)
    mt = np.zeros(124)

    # 记录验证集的loss随迭代次数的值
    val_losses = []

    for num in range(epoch):

        # 通过SGD更新参数，随机选择10个样本
        sample_indices = random.sample(range(X_test.shape[0]), 100)
        # 获得loss
        val_loss = get_loss(X_test, y_test, w, b)

        w, b, Gt, mt = Adam(X_test, y_test, w, b, Gt, mt, sample_indices, learning_rate, num + 1)

        # 将loss加入列表
        val_losses.append(val_loss)
        print("Adam: ", num, val_loss)
    return val_losses


if __name__ == "__main__":

    # 加载数据
    X_train, y_train = get_data(r"E:\machine learning\lab2\a9a")
    X_test, y_test = get_data(r"E:\machine learning\lab2\a9a.t")

    # 将验证集的122个特征末尾补0
    zeros = np.zeros(16281)
    X_test = np.c_[X_test, zeros]

    # 初始化参数
    learning_rate = 0.01
    epoch = 300

    NAG_losses = get_NAG(epoch, learning_rate)
    RMSProp_losses = get_RMSProp(epoch, learning_rate)
    AdaDelta_losses = get_AdaDelta(epoch)
    Adam_losses = get_Adam(epoch, learning_rate)

    # loss随迭代次数的变化图
    plt.plot(range(epoch), NAG_losses, label="NAG_loss", color='red')
    plt.plot(range(epoch), RMSProp_losses, label="RMSProp_loss", color='blue')
    plt.plot(range(epoch), AdaDelta_losses, label="AdaDelta_loss", color='green')
    plt.plot(range(epoch), Adam_losses, label="Adam_loss", color='yellow')
    plt.xlabel("epochs")
    plt.ylabel('loss')
    plt.legend()
    plt.show()
# Out:
# NAG:  0 0.656470732756
# NAG:  1 0.65671641791
# NAG:  2 0.655733677293
# NAG:  3 0.653399668325
# NAG:  4 0.648854492967
# NAG:  5 0.646029113691
# NAG:  6 0.643817947301
# NAG:  7 0.642466678951
# NAG:  8 0.640132669983
# NAG:  9 0.637307290707
# NAG:  10 0.633867698544
# NAG:  11 0.629568208341
# NAG:  12 0.625391560715
# NAG:  13 0.620846385357
# NAG:  14 0.61580983969
# NAG:  15 0.611510349487
# NAG:  16 0.60917634052
# NAG:  17 0.607579387016
# NAG:  18 0.606105276089
# NAG:  19 0.603771267121
# NAG:  20 0.600945887845
# NAG:  21 0.598243351146
# NAG:  22 0.598243351146
# NAG:  23 0.595540814446
# NAG:  24 0.592961120324
# NAG:  25 0.59271543517
# NAG:  26 0.591241324243
# NAG:  27 0.589890055893
# NAG:  28 0.590258583625
# NAG:  29 0.589521528162
# NAG:  30 0.589767213316
# NAG:  31 0.588907315275
# NAG:  32 0.586204778576
# AdaDelta:  286 0.719611817456
# AdaDelta:  287 0.719366132301
# AdaDelta:  288 0.71899760457
# AdaDelta:  289 0.718751919415
# AdaDelta:  290 0.718383391684
# AdaDelta:  291 0.718506234261
# AdaDelta:  292 0.716786438179
# AdaDelta:  293 0.716295067871
# AdaDelta:  294 0.715066642098
# AdaDelta:  295 0.714943799521
# AdaDelta:  296 0.71408390148
# AdaDelta:  297 0.713838216326
# AdaDelta:  298 0.713592531171
# AdaDelta:  299 0.713346846017
# Adam:  0 0.596400712487
# Adam:  1 0.597260610528
# Adam:  2 0.5984890363
# Adam:  3 0.59627786991
# Adam:  4 0.594435231251
# Adam:  5 0.593206805479
# Adam:  6 0.588907315275
# Adam:  7 0.584484982495
# Adam:  8 0.579694121983
# Adam:  9 0.572077882194
# Adam:  10 0.565935753332
# Adam:  11 0.557950985812
# Adam:  12 0.555125606535
# Adam:  13 0.551563171795
# Adam:  14 0.54689515386
# Adam:  15 0.542104293348
# Adam:  16 0.538296173454
# Adam:  17 0.534733738714
# Adam:  18 0.533873840673
# Adam:  19 0.532768257478
# Adam:  20 0.532276887169
# Adam:  21 0.530802776242
# Adam:  22 0.529205822738
# Adam:  23 0.52822308212
# Adam:  24 0.526134758307
# Adam:  25 0.527608869234
# Adam:  26 0.526626128616
# Adam:  27 0.524292119649
# Adam:  28 0.524292119649
# Adam:  29 0.524292119649
# Adam:  30 0.524169277071
# Adam:  31 0.524906332535
# Adam:  32 0.525643387998
# Adam:  33 0.524537804803
# Adam:  34 0.524906332535
# Adam:  35 0.526380443462
# Adam:  36 0.525274860267
# Adam:  37 0.524046434494
# Adam:  38 0.522080953258
# Adam:  39 0.520606842332
# Adam:  40 0.519009888827
# Adam:  41 0.516921565014
# Adam:  42 0.513604815429
# Adam:  43 0.512130704502
# Adam:  44 0.510042380689
# Adam:  45 0.507831214299
# Adam:  46 0.506848473681
# Adam:  47 0.506479945949
# Adam:  48 0.504637307291
# Adam:  49 0.503654566673
# Adam:  50 0.503900251827
# Adam:  51 0.503163196364
# Adam:  52 0.501811928014
# Adam:  53 0.500829187396
# Adam:  54 0.498863706161
# Adam:  55 0.497512437811
# Adam:  56 0.495424113998
# Adam:  57 0.494564215957
# Adam:  58 0.490633253486
# Adam:  59 0.487439346477
# Adam:  60 0.485719550396
# Adam:  61 0.483508384006
# Adam:  62 0.481911430502
# Adam:  63 0.480928689884
# Adam:  64 0.481051532461
# Adam:  65 0.480314476998
# Adam:  66 0.480314476998
# Adam:  67 0.479823106689
# Adam:  68 0.479208893803
# Adam:  69 0.478840366071
# Adam:  70 0.478963208648
# Adam:  71 0.47712056999
# Adam:  72 0.474663718445
# Adam:  73 0.471592654014
# Adam:  74 0.467661691542
# Adam:  75 0.46422209938
# Adam:  76 0.461273877526
# Adam:  77 0.459062711136
# Adam:  78 0.45574596155
# Adam:  79 0.454271850623
# Adam:  80 0.452552054542
# Adam:  81 0.448989619802
# Adam:  82 0.447146981144
# Adam:  83 0.445795712794
# Adam:  84 0.446655610835
# Adam:  85 0.447146981144
# Adam:  86 0.445427185062
# Adam:  87 0.443707388981
# Adam:  88 0.444567287022
# Adam:  89 0.442356120631
# Adam:  90 0.441127694859
# Adam:  91 0.440390639396
# Adam:  92 0.440144954241
# Adam:  93 0.441127694859
# Adam:  94 0.441373380014
# Adam:  95 0.4419875929
# Adam:  96 0.441741907745
# Adam:  97 0.440759167127
# Adam:  98 0.445918555371
# Adam:  99 0.449849517843
# Adam:  100 0.449358147534
# Adam:  101 0.448989619802
# Adam:  102 0.452060684233
# Adam:  103 0.452920582274
# Adam:  104 0.453780480314
# Adam:  105 0.452920582274
# Adam:  106 0.454149008046
# Adam:  107 0.455377433819
# Adam:  108 0.455623118973
# Adam:  109 0.454517535778
# Adam:  110 0.453289110006
# Adam:  111 0.452552054542
# Adam:  112 0.452429211965
# Adam:  113 0.451446471347
# Adam:  114 0.450709415884
# Adam:  115 0.448743934648
# Adam:  116 0.448498249493
# Adam:  117 0.447638351453
# Adam:  118 0.448621092071
# Adam:  119 0.447884036607
# Adam:  120 0.447515508875
# Adam:  121 0.447024138566
# Adam:  122 0.446164240526
# Adam:  123 0.443338861249
# Adam:  124 0.442478963209
# Adam:  125 0.441373380014
# Adam:  126 0.437688102696
# Adam:  127 0.434985565997
# Adam:  128 0.430563233217
# Adam:  129 0.428720594558
# Adam:  130 0.427983539095
# Adam:  131 0.426755113322
# Adam:  132 0.4268779559
# Adam:  133 0.425772372704
# Adam:  134 0.424052576623
# Adam:  135 0.423684048891
# Adam:  136 0.42552668755
# Adam:  137 0.426018057859
# Adam:  138 0.427369326208
# Adam:  139 0.429826177753
# Adam:  140 0.432283029298
# Adam:  141 0.435354093729
# Adam:  142 0.435722621461
# Adam:  143 0.43707388981
# Adam:  144 0.435599778883
# Adam:  145 0.434248510534
# Adam:  146 0.432283029298
# Adam:  147 0.431545973835
# Adam:  148 0.430194705485
# Adam:  149 0.42994902033
# Adam:  150 0.426140900436
# Adam:  151 0.421841410233
# Adam:  152 0.419261716111
# Adam:  153 0.416804864566
# Adam:  154 0.414470855599
# Adam:  155 0.411768318899
# Adam:  156 0.409311467355
# Adam:  157 0.407837356428
# Adam:  158 0.405994717769
# Adam:  159 0.405626190037
# Adam:  160 0.404397764265
# Adam:  161 0.40464344942
# Adam:  162 0.403169338493
# Adam:  163 0.402432283029
# Adam:  164 0.401449542411
# Adam:  165 0.402309440452
# Adam:  166 0.405380504883
# Adam:  167 0.408083041582
# Adam:  168 0.410662735704
# Adam:  169 0.411768318899
# Adam:  170 0.416804864566
# Adam:  171 0.421472882501
# Adam:  172 0.423069836005
# Adam:  173 0.425649530127
# Adam:  174 0.430931760948
# Adam:  175 0.436459676924
# Adam:  176 0.439039371046
# Adam:  177 0.439407898778
# Adam:  178 0.438302315583
# Adam:  179 0.434617038265
# Adam:  180 0.428474909404
# Adam:  181 0.423684048891
# Adam:  182 0.421350039924
# Adam:  183 0.418647503225
# Adam:  184 0.413488114981
# Adam:  185 0.411031263436
# Adam:  186 0.409925680241
# Adam:  187 0.409557152509
# Adam:  188 0.409802837664
# Adam:  189 0.408451569314
# Adam:  190 0.407100300964
# Adam:  191 0.405626190037
# Adam:  192 0.404766291997
# Adam:  193 0.403660708802
# Adam:  194 0.402063755298
# Adam:  195 0.399484061176
# Adam:  196 0.398009950249
# Adam:  197 0.396412996745
# Adam:  198 0.394447515509
# Adam:  199 0.394324672932
# Adam:  200 0.394324672932
# Adam:  201 0.393096247159
# Adam:  202 0.393219089737
# Adam:  203 0.394570358086
# Adam:  204 0.396904367054
# Adam:  205 0.398255635403
# Adam:  206 0.39837847798
# Adam:  207 0.398992690867
# Adam:  208 0.399361218598
# Adam:  209 0.402555125607
# Adam:  210 0.402677968184
# Adam:  211 0.401818070143
# Adam:  212 0.402063755298
# Adam:  213 0.40108101468
# Adam:  214 0.399484061176
# Adam:  215 0.397764265094
# Adam:  216 0.3939561452
# Adam:  217 0.394324672932
# Adam:  218 0.393219089737
# Adam:  219 0.39039371046
# Adam:  220 0.389779497574
# Adam:  221 0.38904244211
# Adam:  222 0.388796756956
# Adam:  223 0.388551071801
# Adam:  224 0.388305386647
# Adam:  225 0.387445488606
# Adam:  226 0.388551071801
# Adam:  227 0.39039371046
# Adam:  228 0.392113506541
# Adam:  229 0.395921626436
# Adam:  230 0.397150052208
# Adam:  231 0.39972974633
# Adam:  232 0.402677968184
# Adam:  233 0.407100300964
# Adam:  234 0.412136846631
# Adam:  235 0.420981512192
# Adam:  236 0.427123641054
# Adam:  237 0.429580492599
# Adam:  238 0.432774399607
# Adam:  239 0.435231251152
# Adam:  240 0.435722621461
# Adam:  241 0.433142927339
# Adam:  242 0.423069836005
# Adam:  243 0.415822123948
# Adam:  244 0.409188624777
# Adam:  245 0.401818070143
# Adam:  246 0.398992690867
# Adam:  247 0.397150052208
# Adam:  248 0.396535839322
# Adam:  249 0.391622136232
# Adam:  250 0.391499293655
# Adam:  251 0.389656654997
# Adam:  252 0.390639395615
# Adam:  253 0.392113506541
# Adam:  254 0.392850562005
# Adam:  255 0.391130765923
# Adam:  256 0.39260487685
# Adam:  257 0.396044469013
# Adam:  258 0.402432283029
# Adam:  259 0.408942939623
# Adam:  260 0.409925680241
# Adam:  261 0.411154106013
# Adam:  262 0.414102327867
# Adam:  263 0.416804864566
# Adam:  264 0.416559179412
# Adam:  265 0.417173392298
# Adam:  266 0.415085068485
# Adam:  267 0.412259689208
# Adam:  268 0.406608930655
# Adam:  269 0.403660708802
# Adam:  270 0.401695227566
# Adam:  271 0.400958172102
# Adam:  272 0.403537866224
# Adam:  273 0.402800810761
# Adam:  274 0.404766291997
# Adam:  275 0.405257662306
# Adam:  276 0.397272894785
# Adam:  277 0.393833302623
# Adam:  278 0.393341932314
# Adam:  279 0.392482034273
# Adam:  280 0.39174497881
# Adam:  281 0.391622136232
# Adam:  282 0.388796756956
# Adam:  283 0.386339905411
# Adam:  284 0.386094220257
# Adam:  285 0.391130765923
# Adam:  286 0.399361218598
# Adam:  287 0.409925680241
# Adam:  288 0.4268779559
# Adam:  289 0.43621399177
# Adam:  290 0.433142927339
# Adam:  291 0.425158159818
# Adam:  292 0.413610957558
# Adam:  293 0.400835329525
# Adam:  294 0.393833302623
# Adam:  295 0.385602849948
# Adam:  296 0.380566304281
# Adam:  297 0.377372397273
# Adam:  298 0.373564277379
# Adam:  299 0.372458694183
